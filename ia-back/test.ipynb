# %%
import numpy as np

a = np.array([[1, 2, 3], [4, 5, 6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import pandas as pd

# data = {
#   'Name': ['Alice', 'Bob', 'Charlie'],
#   'Age': [20, 30, 35],
#   'City': ['New York', 'Los Angeles', 'Chicago']
# }

df = pd.read_csv('./data/data.csv', sep=';')
print(df)
# Out:
#     id  nbRooms  surface  nbWindows       price
# 0    1        4    40.04          2   549338.73
# 1    2        4   125.58          5  1037061.08
# 2    3        2   117.19          6  1025764.62
# 3    4        5   121.27          1  1109059.81
# 4    5        3   205.25          4  2788208.50
# 5    6        1   249.00          4  3388245.68
# 6    7        1   208.32          7  2861332.79
# 7    8        1    96.42          1   981538.33
# 8    9        2   152.63          5  1936029.99
# 9   10        5   153.70          1  1500750.12
# 10  11        1    32.70         10   424770.68
# 11  12        6   180.63          7  2223306.83
# 12  13        6   103.37          7  1035571.42
# 13  14        1   192.02          6  1864077.64
# 14  15        6   162.69          2  2013805.19
# 15  16        6    35.41          9   385195.61
# 16  17        2   142.37          6  1987398.26
# 17  18        5   246.16         10  2045773.84
# 18  19        6   149.60          1  1704028.90
# 19  20        4   142.80          9  1651871.21
# 20  21        5   192.39          4  1973534.60
# 21  22        3    83.74          8   750152.08
# 22  23        4   232.80          2  2112407.41
# 23  24        5    25.94          9   348842.03
# 24  25        6    34.56          8   317411.07
# 25  26        6    35.54          9   490830.80
# 26  27        3   150.70          6  1947438.34
# 27  28        6   195.89          7  1599032.06
# 28  29        6    24.81          4   298222.20
# 29  30        6   228.81          1  3186617.58
# 30  31        6   201.91          4  1757934.84
# 31  32        1   158.29          1  2082792.15
# 32  33        6    75.41          6   657448.72
# 33  34        5   183.28          7  2327170.25
# 34  35        6   143.47          7  1200340.85
# 35  36        1   237.42          6  2728646.06
# 36  37        1   113.30          8  1164061.28
# 37  38        5   107.99          7  1158056.35
# 38  39        6   216.29          8  2924645.42
# 39  40        5    67.90          4   674428.54
# 40  41        2    46.81          8   581281.29
# 41  42        6   214.71          2  2289519.45
# 42  43        3    34.21         10   415426.18
# 43  44        5   144.53          7  1916740.10
# 44  45        1    55.62          4   530839.46
# 45  46        1   237.36          6  2170237.37
# 46  47        4   124.03          7  1382939.24
# 47  48        6   189.24         10  2570181.93
# 48  49        6    24.06         10   252674.21
# 49  50        4    85.10          2  1082436.85
# 50  51        3    70.00          5   303000.77
# 51  52        4    90.00          7   450000.77
